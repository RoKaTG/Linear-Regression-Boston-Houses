# %%
#importation des librairies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import plotly.graph_objs as go
# from plotly.offline import iplot
import matplotlib.cm as cm
import seaborn as sns
plt.ion()

# %% [markdown]
# # Récuperation des Données

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = 10
dataset = pd.read_csv('kc_house_data.csv')  #récuperation du dataset
display(dataset)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# 1             2570      7242     2.0           0     0          3      7
# 2              770     10000     1.0           0     0          3      6
# 3             1960      5000     1.0           0     0          5      7
# 4             1680      8080     1.0           0     0          3      8
# ...            ...       ...     ...         ...   ...        ...    ...
# 21608         1530      1131     3.0           0     0          3      8
# 21609         2310      5813     2.0           0     0          3      8
# 21610         1020      1350     2.0           0     0          3      7
# 21611         1600      2388     2.0           0     0          3      8
# 21612         1020      1076     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
dataset.shape #Affichage du nombres de lignes et de colonnes
# Out:
# (21613, 21)

# %%
print(dataset.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#L'ensemble des types de données des classes et si elle comporte des valeurs non-null
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
#Check si il y'a des valeurs null (manquante dans la dataset)
dataset.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
#                 ..
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# Length: 21, dtype: int64

# %% [markdown]
# Il n'y a aucune valeur null donc le dataset est complet

# %%
dataset.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# Nous pouvons dès à présent relevés certains chiffres qui semblent être intéressant :
#
# - certaines features sont des valeurs qualitatives : waterfront, view, condition, grade et yr_renovated qui est égale à l'année de rénovation si la maison a été rénové, 0 sinon.
#
# - Les statistiques de sqft_living, sqft_basement, sqft_lot15 semblent avoir une valeur abérante:
#     - sqft_living: les quartiles nous indique que la moyenne des maisons est d'environ entre 1420 et 2550 m² d'espace habitable,avec une moyenne de 2079m² tandis que la valeur maximale est de 13540m²
#
#     - sqft_basement: les quartiles nous indique que la majorité des valeurs de cette variable est autour                               de 0m² et une autre autour de 560m² alors que on a une valeur maximale à 4820m²
#
#     - bedrooms: les quartiles nous indique que la majorité des des valeurs de cette variable est autour                               de 3/4 chambres alors que nous avons une valeur maximale de 33 chambres.

# %%
dataset.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %% [markdown]
# # Exploration des données

# %% [markdown]
# Nous allons donc chercher une corélation entre 2 variables dont le prix qui est notre objectif final:

# %% [markdown]
# PRIX ET SQFT_LIVING :

# %% [markdown]
# Etant donné que la surface habitable est un critère important sur le prix, nous allons donc explorer les données

# %%
plt.plot(dataset['sqft_living'],dataset['price'],".")
plt.xlabel("sqft_living")
plt.ylabel("price")
plt.title("Prix de vente en fonction de la surface habitable")
plt.show()

# %% [markdown]
# Remarques :
#     - La majorité des ventes sont entre 300m² et 6000m² avec comme prix de vente entre 75000 et 280$

# %% [markdown]
# PRIX ET ID:

# %% [markdown]
# Nous allons maintenant voir si l'id peut avoir une bonne corélation avec le prix :

# %%
plt.plot(dataset['id'],dataset['price'],".")
plt.xlabel("id")
plt.ylabel("price")
plt.title("Prix de vente en fonction de l'id")
# Out:
# Text(0.5, 1.0, "Prix de vente en fonction de l'id")

# %% [markdown]
# Nous remarquons uniquement que la majorité des ventes est en dessous de 200 000$ quelque sois l'id de vente.Il n'y a donc pas de corélation entre ces 2 variables (nous aurions pu penser que les id étaient donnée en fonction du prix de vente)

# %% [markdown]
# PRIX ET CHAMBRES :

# %%
plt.plot(dataset['bedrooms'],dataset['price'],".")
plt.xlabel("bedrooms")
plt.ylabel("price")
plt.title("Prix de vente en fonction du nombre de chambre")
plt.show()

# %% [markdown]
# Ayant une potentielle corrélation entre le nombre de chambres et le prix, nous allons affiné la data :

# %%
#Cherchons les différentes valeurs de chambres présente dans le dataset:
dataset.bedrooms.unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %%
test = dataset.groupby('bedrooms').price.mean()          #Graphique prix par rapport à la moyenne de chambre
sns.barplot(x=test.index,y=test.values,palette="rocket")
plt.xlabel("Nombre de chambres")
plt.ylabel("Price")
plt.title("Prix de vente en fonction du nombre de chambres")
# Out:
# Text(0.5, 1.0, 'Prix de vente en fonction du nombre de chambres')

# %% [markdown]
# On remarque une net augmentation de la moyenne du prix de vente jusqu'à 8 chambres jusqu'à atteindre son maximum à 8 puis redescendre jusqu'à 11 puis remonter à son extremum c'est à dire 33.

# %% [markdown]
# Passons maintenant au prix de vente de chaque maison en fonction du nombre de chambres.

# %%
plt.figure(figsize=(10, 10))
ax = sns.boxplot(x="bedrooms", y="price", data=dataset)

# %%
plt.scatter(x= dataset['long'], y= dataset['lat'], c=dataset['price'], cmap='Spectral')
plt.colorbar()
plt.title('Prix de vente en fonction de la latitutde et longitude')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()

# %%
dataset.hist(bins = 20, figsize = (20,20), color = 'r')        #Plot de touts nos labels
# sns.pairplot(dataset)
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'sqft_living'}>,
#         <AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>],
#        [<AxesSubplot:title={'center':'view'}>,
#         <AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>],
#        [<AxesSubplot:title={'center':'sqft_basement'}>,
#         <AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>],
#        [<AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'long'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>,
#         <AxesSubplot:title={'center':'sqft_lot15'}>]], dtype=object)

# %%
f, ax = plt.subplots(figsize = (20, 20))                #Heatmap de correlation
sns.heatmap(dataset.corr(), annot = True, linewidths=.05);

# %% [markdown]
# # Raffinage des données

# %% [markdown]
# ## Suppression de la donnée aberrante

# %%
dataset_r = dataset.drop(index=dataset[dataset["bedrooms"]==33].index)

# %% [markdown]
# ## Suppression des features inutiles

# %%
dataset_r.drop(columns=["id","sqft_lot15","long","zipcode","yr_built","condition","sqft_lot"],inplace=True)
dataset_r.head(3)
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  floors  \
# 0  20141013T000000  221900.0         3       1.00         1180     1.0
# 1  20141209T000000  538000.0         3       2.25         2570     2.0
# 2  20150225T000000  180000.0         2       1.00          770     1.0
#
#    waterfront  view  grade  sqft_above  sqft_basement  yr_renovated      lat  \
# 0           0     0      7        1180              0             0  47.5112
# 1           0     0      7        2170            400          1991  47.7210
# 2           0     0      6         770              0             0  47.7379
#
#    sqft_living15
# 0           1340
# 1           1690
# 2           2720

# %% [markdown]
# ## Formatage des features

# %% [markdown]
# ### mise en forme de la date
#
# La date est une chaine de caractère au format:
#
#        YearMoDaT000000
#     ex:20150225T000000
#
# on veut passer à une valeur entière plus exploitable:
#
#     ex:20150225

# %%
dataset_r["date"] = dataset_r["date"].transform(lambda x: x[:8])
dataset_r["date"] = dataset_r["date"].transform(lambda x: int(x))
dataset_r.head(3)
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0  20141013  221900.0         3       1.00         1180     1.0           0
# 1  20141209  538000.0         3       2.25         2570     2.0           0
# 2  20150225  180000.0         2       1.00          770     1.0           0
#
#    view  grade  sqft_above  sqft_basement  yr_renovated      lat  \
# 0     0      7        1180              0             0  47.5112
# 1     0      7        2170            400          1991  47.7210
# 2     0      6         770              0             0  47.7379
#
#    sqft_living15
# 0           1340
# 1           1690
# 2           2720

# %%
Y = dataset_r["price"]
X = dataset_r.drop("price", axis=1)

# %%
from sklearn.model_selection import train_test_split   #Création du train et test split avec 40% pour 60% de train

test_size = 0.4
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=10)
X_train.shape
# Out:
# (12967, 13)

# %% [markdown]
# # Choix du modèle

# %% [markdown]
# ## Régression Linéaire

# %%
#les modeles
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
# from yellowbrick import PredictionError
#Pour l'optimisation
from sklearn.model_selection import GridSearchCV
#Pour l'evaluation des modeles
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
models = []
seed = 42 #On aura le meme resultat a chaque fois

models.append(
    ("Linear Regression", 
    Pipeline(
        [# [("Scaler", StandardScaler()), 
        ("Lin_Reg", LinearRegression())])
    )
)

models.append(
    ("Ridge Regression",
     Pipeline(
        [#  [("Scaler", StandardScaler()),
          ("Ridge", Ridge(random_state=seed, alpha=1.0))])
     )
)

models.append(
    ("Random Forest Regression",
     Pipeline(
        [#  [("Scaler", StandardScaler()),
          ("Random Forest", RandomForestRegressor(random_state=seed))])
     )
)

models.append(
    ("KNN Regression",
     Pipeline(
         [("Scaler", StandardScaler()),
          ("KNN", KNeighborsRegressor())])
     )
)

# %%
#Differente methode d'evaluation : "mean_squared_error", "mean_absolute_error", "r2"
scoring = 'r2'
n_folds = 10
N, train_score, val_score, results, names = [], [], [] , [], []

for name, model in models:

    kfold = KFold(n_splits=n_folds)
    cross_val_results = cross_val_score(model, X_train, y_train, cv=kfold,
                                 scoring=scoring, n_jobs=-1)
    N, train_score, val_score = learning_curve(model, X_train, y_train, cv = kfold)

    names.append(name)
    results.append(cross_val_results)

    msg = "%s: %f (+/- %f)" % (name, cross_val_results.mean() * 100,  cross_val_results.std() * 100)
    print(msg)

    plt.plot(N, train_score.mean(axis=1), label="train")
    plt.plot(N, val_score.mean(axis=1), label="validation")
    plt.xlabel('train_sizes')
    plt.ylabel('score') 
    plt.legend()
    plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning: resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
#   warnings.warn('resource_tracker: process died unexpectedly, '
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/runpy.py", line 188, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/opt/conda/lib/python3.9/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/opt/conda/lib/python3.9/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/opt/conda/lib/python3.9/site-packages/joblib/memory.py", line 32, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/opt/conda/lib/python3.9/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from .backports import concurrency_safe_rename
#   File "/opt/conda/lib/python3.9/site-packages/joblib/backports.py", line 13, in <module>
#     import numpy as np
#   File "/opt/conda/lib/python3.9/site-packages/numpy/__init__.py", line 157, in <module>
#     from . import ma
#   File "/opt/conda/lib/python3.9/site-packages/numpy/ma/__init__.py", line 42, in <module>
#     from . import core
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 982, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# OSError: [Errno 14] Bad address
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/runpy.py", line 188, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/opt/conda/lib/python3.9/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/opt/conda/lib/python3.9/site-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/opt/conda/lib/python3.9/site-packages/joblib/memory.py", line 32, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/opt/conda/lib/python3.9/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from .backports import concurrency_safe_rename
#   File "/opt/conda/lib/python3.9/site-packages/joblib/backports.py", line 13, in <module>
#     import numpy as np
#   File "/opt/conda/lib/python3.9/site-packages/numpy/__init__.py", line 153, in <module>
#     from . import fft
#   File "/opt/conda/lib/python3.9/site-packages/numpy/fft/__init__.py", line 203, in <module>
#     from . import _pocketfft, helper
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 982, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# OSError: [Errno 14] Bad address
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/runpy.py", line 188, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/opt/conda/lib/python3.9/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/joblib/__init__.py", line 113, in <module>
#   File "/opt/conda/lib/python3.9/runpy.py", line 188, in _run_module_as_main
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/opt/conda/lib/python3.9/site-packages/joblib/memory.py", line 32, in <module>
#     from ._store_backends import StoreBackendBase, FileSystemStoreBackend
#   File "/opt/conda/lib/python3.9/site-packages/joblib/_store_backends.py", line 15, in <module>
#     from .backports import concurrency_safe_rename
#   File "/opt/conda/lib/python3.9/site-packages/joblib/backports.py", line 13, in <module>
#     import numpy as np
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/opt/conda/lib/python3.9/site-packages/numpy/__init__.py", line 157, in <module>
#   File "/opt/conda/lib/python3.9/runpy.py", line 111, in _get_module_details
#     __import__(pkg_name)
#   File "/opt/conda/lib/python3.9/site-packages/joblib/__init__.py", line 120, in <module>
#     from . import ma
#   File "/opt/conda/lib/python3.9/site-packages/numpy/ma/__init__.py", line 42, in <module>
#     from . import core
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     from .parallel import Parallel
#   File "/opt/conda/lib/python3.9/site-packages/joblib/parallel.py", line 26, in <module>
#     from ._parallel_backends import (FallbackToBackend, MultiprocessingBackend,
#   File "/opt/conda/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 17, in <module>
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#     from .pool import MemmappingPool
#   File "/opt/conda/lib/python3.9/site-packages/joblib/pool.py", line 31, in <module>
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 982, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# OSError: [Errno 14] Bad address
#   File "/opt/conda/lib/python3.9/site-packages/joblib/_memmapping_reducer.py", line 37, in <module>
#   File "/opt/conda/lib/python3.9/site-packages/joblib/externals/loky/__init__.py", line 12, in <module>
#   File "/opt/conda/lib/python3.9/site-packages/joblib/externals/loky/backend/reduction.py", line 125, in <module>
#   File "/opt/conda/lib/python3.9/site-packages/joblib/externals/cloudpickle/__init__.py", line 4, in <module>
#   File "/opt/conda/lib/python3.9/site-packages/joblib/externals/cloudpickle/cloudpickle.py", line 64, in <module>
#     import typing_extensions as _typing_extensions
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 982, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# OSError: [Errno 14] Bad address
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [54], in <cell line: 6>()
#       6 for name, model in models:
#       8     kfold = KFold(n_splits=n_folds)
# ----> 9     cross_val_results = cross_val_score(model, X_train, y_train, cv=kfold,
#      10                                  scoring=scoring, n_jobs=-1)
#      11     N, train_score, val_score = learning_curve(model, X_train, y_train, cv = kfold)
#      13     names.append(name)
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:510, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507 # To ensure multimetric format is not supported
#     508 scorer = check_scoring(estimator, scoring=scoring)
# --> 510 cv_results = cross_validate(
#     511     estimator=estimator,
#     512     X=X,
#     513     y=y,
#     514     groups=groups,
#     515     scoring={"score": scorer},
#     516     cv=cv,
#     517     n_jobs=n_jobs,
#     518     verbose=verbose,
#     519     fit_params=fit_params,
#     520     pre_dispatch=pre_dispatch,
#     521     error_score=error_score,
#     522 )
#     523 return cv_results["test_score"]
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File /opt/conda/lib/python3.9/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File /opt/conda/lib/python3.9/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File /opt/conda/lib/python3.9/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File /opt/conda/lib/python3.9/site-packages/joblib/_parallel_backends.py:531, in LokyBackend.apply_async(self, func, callback)
#     529 def apply_async(self, func, callback=None):
#     530     """Schedule a func to be run"""
# --> 531     future = self._workers.submit(SafeFunction(func))
#     532     future.get = functools.partial(self.wrap_future_result, future)
#     533     if callback is not None:
#
# File /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/reusable_executor.py:177, in _ReusablePoolExecutor.submit(self, fn, *args, **kwargs)
#     175 def submit(self, fn, *args, **kwargs):
#     176     with self._submit_resize_lock:
# --> 177         return super(_ReusablePoolExecutor, self).submit(
#     178             fn, *args, **kwargs)
#
# File /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:1135, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#    1132 # Wake up queue management thread
#    1133 self._executor_manager_thread_wakeup.wakeup()
# -> 1135 self._ensure_executor_running()
#    1136 return f
#
# File /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:1109, in ProcessPoolExecutor._ensure_executor_running(self)
#    1107 with self._processes_management_lock:
#    1108     if len(self._processes) != self._max_workers:
# -> 1109         self._adjust_process_count()
#    1110     self._start_executor_manager_thread()
#
# File /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:1087, in ProcessPoolExecutor._adjust_process_count(self)
#    1085 def _adjust_process_count(self):
#    1086     for _ in range(len(self._processes), self._max_workers):
# -> 1087         worker_exit_lock = self._context.BoundedSemaphore(1)
#    1088         args = (self._call_queue, self._result_queue, self._initializer,
#    1089                 self._initargs, self._processes_management_lock,
#    1090                 self._timeout, worker_exit_lock, _CURRENT_DEPTH + 1)
#    1091         worker_exit_lock.acquire()
#
# File /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/backend/context.py:322, in LokyContext.BoundedSemaphore(self, value)
#     320 """Returns a bounded semaphore object"""
#     321 from .synchronize import BoundedSemaphore
# --> 322 return BoundedSemaphore(value)
#
# File /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py:162, in BoundedSemaphore.__init__(self, value)
#     161 def __init__(self, value=1):
# --> 162     SemLock.__init__(self, SEMAPHORE, value, value)
#
# File /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/backend/synchronize.py:70, in SemLock.__init__(self, kind, value, maxvalue, name)
#      68 for i in range(100):
#      69     try:
# ---> 70         self._semlock = _SemLock(
#      71             kind, value, maxvalue, SemLock._make_name(), unlink_now
#      72         )
#      73     except FileExistsError:  # pragma: no cover
#      74         pass
#
# OSError: [Errno 12] Cannot allocate memory

# %% [markdown]
# # Polynome Degre 2

# %%
#Differente methode d'evaluation : "mean_squared_error", "mean_absolute_error", "r2"
scoring = 'r2'
n_folds = 10
N, train_score, val_score, results, names = [], [], [] , [], []
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_TRANS = poly.fit_transform(X_train)

for name, model in models:

    kfold = KFold(n_splits=n_folds)
    cross_val_results = cross_val_score(model, X_train_TRANS, y_train, cv=kfold,
                                 scoring=scoring, n_jobs=-1)
    N, train_score, val_score = learning_curve(model, X_train_TRANS, y_train, cv = kfold)

    names.append(name)
    results.append(cross_val_results)

    msg = "%s: %f (+/- %f)" % (name, cross_val_results.mean() * 100,  cross_val_results.std() * 100)
    print(msg)

    plt.plot(N, train_score.mean(axis=1), label="train")
    plt.plot(N, val_score.mean(axis=1), label="validation")
    plt.xlabel('train_sizes')
    plt.ylabel('score') 
    plt.legend()
    plt.show()

# %% [markdown]
# # Optimisation

# %%
from sklearn.model_selection import GridSearchCV

#Optimisation du randomforest parce que meilleure performance
param_dict = {
    'bootstrap': [True, False],
    'max_depth': [10,25,50,75,80],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [5,8, 10, 12],
    'n_estimators': [50,65,75,80,90,100, 120]
}

grid = GridSearchCV(estimator=RandomForestRegressor(random_state=42), param_grid=param_dict, cv=3, n_jobs=-1, verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 13>()
#       3 #Optimisation du randomforest parce que meilleure performance
#       4 param_dict = {
#       5     'bootstrap': [True, False],
#       6     'max_depth': [10,25,50,75,80],
#    (...)
#      10     'n_estimators': [50,65,75,80,90,100, 120]
#      11 }
# ---> 13 grid = GridSearchCV(estimator=RandomForestRegressor(random_state=42), param_grid=param_dict, cv=3, n_jobs=-1, verbose=2)
#
# NameError: name 'RandomForestRegressor' is not defined

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 1680 candidates, totalling 5040 fits
# /opt/conda/lib/python3.9/site-packages/joblib/externals/loky/backend/resource_tracker.py:120: UserWarning: resource_tracker: process died unexpectedly, relaunching.  Some folders/sempahores might leak.
#   warnings.warn('resource_tracker: process died unexpectedly, '

# %%
rf_best_param = grid.best_params_
print(rf_best_param)
best_rf = grid.best_estimator_

# %%
k_range = range(1, 30)
param_dict = {
    "n_neighbors" : k_range,
    "weights" : ['uniform', 'distance']
}

grid = GridSearchCV(estimator=KNeighborsRegressor(), param_grid=param_dict, cv=5, n_jobs=-1, verbose=2)

# %%
grid.fit(X_train, y_train)

# %%
kn_best_param = grid.best_params_
print(kn_best_param)
best_kn = grid.best_estimator_

# %%
best_rf

# %%
best_rf.score(X_test, y_test)

# %%
best_kn.score(X_test, y_test)

# %%
feature_imp = pd.Series(best_rf.feature_importances_,
                        index=X_train.columns).sort_values(ascending=False)
feature_imp

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %% [markdown]
# # Brouillon

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_TRANSF = poly.fit_transform(X_train)

# %%
poly = PolynomialFeatures(degree=2)

# %%
X_TRANSF = poly.fit_transform(X_train)

# %%
X_TRANSF.shape

# %%
y_train.shape

# %%
model = LinearRegression()

model.fit(X_TRANSF, y_train)

# %%
X_TRANSF_TEST = poly.fit_transform(X_test)

# %%
model.score(X_TRANSF_TEST, y_test)

# %% [markdown]
# # Concentration sur Randomforest

# %%
from sklearn.model_selection import GridSearchCV

#Optimisation du randomforest parce que meilleure performance deja
param_dict = {
    'bootstrap': [True, False],
    'max_depth': [5,10,20],
    'min_samples_leaf': [3,4,5],
    'min_samples_split': [2,3,5],
    'n_estimators': [50,100]
}

grid = GridSearchCV(estimator=RandomForestRegressor(random_state=42), param_grid=param_dict, cv=3, n_jobs=-1, verbose=2)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_TRANS = poly.fit_transform(X_train)

# %%
grid.fit(X_train_TRANS, y_train)

# %%
kn_best_param = grid.best_params_
print(kn_best_param)
best_r = grid.best_estimator_

# %%
X_test_TRANS = poly.fit_transform(X_test)

# %%
best_r.score(X_test_TRANS, y_test)

# %%
best_r.score(X_train_TRANS, y_train)
